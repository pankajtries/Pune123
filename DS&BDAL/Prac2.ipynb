# %% [markdown]
# <a href="https://colab.research.google.com/github/PankajAgarwalS/TE-COMP-SEM-6/blob/main/Prac2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv('academic.csv')
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       Kuwait    lowerlevel    G-04         A
# 1        M          KW       Kuwait    lowerlevel    G-04         A
# 2        M          KW       Kuwait    lowerlevel    G-04         A
# 3        M          KW       Kuwait    lowerlevel    G-04         A
# 4        M          KW       Kuwait    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               424 non-null    float64
#  10  VisITedResources          404 non-null    float64
#  11  AnnouncementsView         403 non-null    float64
#  12  Discussion                412 non-null    float64
# ...

# %%
df.sample(5)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID   Topic  \
# 321      F      Jordan       Jordan    lowerlevel    G-02         A  French
# 169      M          KW       Kuwait    lowerlevel    G-02         B  French
# 186      M          KW       Kuwait  MiddleSchool    G-08         A  Arabic
# 96       F          KW       Kuwait    lowerlevel    G-02         C      IT
# 104      M          KW       Kuwait    lowerlevel    G-02         B      IT
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 321        S      Mum          NaN               NaN                NaN
# 169        S      Mum         30.0              12.0               29.0
# 186        S      Mum         85.0              15.0               22.0
# 96         F   Father          NaN               NaN               11.0
# 104        F   Father          0.0              12.0                3.0
#
#      Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   424.000000        404.000000         403.000000  412.000000
# mean     46.943396         55.472772          39.138958   45.225728
# std      30.869689         32.950700          27.267161   28.019806
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   21.000000
# 50%      50.000000         69.500000          37.000000   40.000000
# 75%      76.250000         84.000000          62.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
sns.boxplot(data=df, orient="h")
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                     0
# raisedhands                 56
# VisITedResources            76
# AnnouncementsView           77
# Discussion                  68
# ParentAnsweringSurvey       15
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
df['raisedhands']=df['raisedhands'].fillna(df['raisedhands'].mean)
df.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                     0
# raisedhands                  0
# VisITedResources            76
# AnnouncementsView           77
# Discussion                  68
# ParentAnsweringSurvey       15
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
df['Discussion']=df['Discussion'].fillna(df['Discussion'].mean)
df.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                     0
# raisedhands                  0
# VisITedResources            76
# AnnouncementsView           77
# Discussion                   0
# ParentAnsweringSurvey       15
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
df['VisITedResources']=df['VisITedResources'].fillna(method='ffill')
df.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                     0
# raisedhands                  0
# VisITedResources             0
# AnnouncementsView           77
# Discussion                   0
# ParentAnsweringSurvey       15
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
df['AnnouncementsView']=df['AnnouncementsView'].fillna(method='ffill')
df.isnull().sum()
# Out:
# gender                       0
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    0
# Topic                        0
# Semester                     0
# Relation                     0
# raisedhands                  0
# VisITedResources             0
# AnnouncementsView            0
# Discussion                   0
# ParentAnsweringSurvey       15
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
df['ParentAnsweringSurvey']=df['ParentAnsweringSurvey'].astype(bool)
df.sample(5)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 239      M       Egypt        Egypt  MiddleSchool    G-07         B  Science
# 455      F      Jordan       Jordan  MiddleSchool    G-08         A  History
# 399      M   Palestine    Palestine  MiddleSchool    G-07         A  Biology
# 337      F   Palestine       Jordan    lowerlevel    G-02         A   French
# 8        F          KW       Kuwait  MiddleSchool    G-07         A     Math
#
#     Semester Relation raisedhands  VisITedResources  AnnouncementsView  \
# 239        S      Mum        92.0              80.0               88.0
# 455        S   Father        39.0              88.0               43.0
# 399        S   Father        89.0              92.0               89.0
# 337        S      Mum        75.0              80.0               15.0
# 8          F   Father        12.0              21.0               16.0
#
#     Discussion  ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df['Discussion'] = pd.to_numeric(df['Discussion'], errors='coerce')
print("Skewness before transformation:", df['Discussion'].skew())
df['Discussion_sqrt'] = np.sqrt(df['Discussion'])

print("Skewness after transformation:", df['Discussion_sqrt'].skew())
# Out:
# Skewness before transformation: 0.2666306793618238
# Skewness after transformation: -0.23078775998009193

# %%
df['raisedhands'] = pd.to_numeric(df['raisedhands'], errors='coerce')

print("Skewness before transformation:")
print(df['raisedhands'].skew())

df['raisedhands_sqrt'] = np.sqrt(df['raisedhands'])

print("Skewness after transformation:")
print(df['raisedhands_sqrt'].skew())
# Out:
# Skewness before transformation:
# 0.01924428890946029
# Skewness after transformation:
# -0.4452838644731815

# %%
df['AnnouncementsView'] = pd.to_numeric(df['AnnouncementsView'], errors='coerce')

print("Skewness before transformation:")
print(df['AnnouncementsView'].skew())

df['AnnouncementsView_sqrt'] = np.sqrt(df['AnnouncementsView'])

print("Skewness after transformation:")
print(df['AnnouncementsView_sqrt'].skew())
# Out:
# Skewness before transformation:
# 0.24663612078608965
# Skewness after transformation:
# -0.470227438593245
